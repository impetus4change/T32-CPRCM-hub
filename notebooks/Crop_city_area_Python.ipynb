# %% [markdown]
# # Crop and Interpolate CPRCM NetCDF Data
#
# This notebook illustrates the cropping and interpolation of CPRCM output NetCDF data for a given city. We will use the common regular longitude-latitude grids defined in https://github.com/impetus4change/T32-CPRCM/tree/main/grids-3i.

# %%
INPUT_PATH = "I4C_CPRCM_DATA"
OUTPUT_PATH = "I4C_CPRCM_CITY_DATA"
